# %%
from datetime import datetime, timedelta
#Задание 1
date_string = 'May 9 2017 9:00AM'
date=datetime.strptime(date_string, '%b %d %Y %H:%M%p')


#Задание 2
date_string = 'May 9 2017 9:00AM'
date=datetime.strptime(date_string, '%b %d %Y %H:%M%p')
date2=date+timedelta(hours=1)
date2
# Out:
# datetime.datetime(2017, 5, 9, 10, 0)

# %%
#Задание 3
date2.strftime( '%Y-%m-%d' )
# Out:
# '2017-05-09'

# %%
#Задание 4
startDate = '2017-01-01'
endDate = '2017-01-03'

startDate_datetime = datetime.strptime(startDate, '%Y-%m-%d')
endDate_datetime = datetime.strptime(endDate, '%Y-%m-%d')
print(startDate_datetime, endDate_datetime)
current_day = startDate_datetime
current_day = startDate_datetime
while current_day <= endDate_datetime:
    print(current_day.strftime('%Y-%m-%d %H:%M:%S'))
    current_day += timedelta(hours=1)
# Out:
# 2017-01-01 00:00:00 2017-01-03 00:00:00
# 2017-01-01 00:00:00
# 2017-01-01 01:00:00
# 2017-01-01 02:00:00
# 2017-01-01 03:00:00
# 2017-01-01 04:00:00
# 2017-01-01 05:00:00
# 2017-01-01 06:00:00
# 2017-01-01 07:00:00
# 2017-01-01 08:00:00
# 2017-01-01 09:00:00
# 2017-01-01 10:00:00
# 2017-01-01 11:00:00
# 2017-01-01 12:00:00
# 2017-01-01 13:00:00
# 2017-01-01 14:00:00
# 2017-01-01 15:00:00
# 2017-01-01 16:00:00
# 2017-01-01 17:00:00
# 2017-01-01 18:00:00
# 2017-01-01 19:00:00
# 2017-01-01 20:00:00
# 2017-01-01 21:00:00
# 2017-01-01 22:00:00
# 2017-01-01 23:00:00
# 2017-01-02 00:00:00
# 2017-01-02 01:00:00
# 2017-01-02 02:00:00
# 2017-01-02 03:00:00
# 2017-01-02 04:00:00
# 2017-01-02 05:00:00
# 2017-01-02 06:00:00
# 2017-01-02 07:00:00
# 2017-01-02 08:00:00
# 2017-01-02 09:00:00
# 2017-01-02 10:00:00
# 2017-01-02 11:00:00
# 2017-01-02 12:00:00
# 2017-01-02 13:00:00
# 2017-01-02 14:00:00
# 2017-01-02 15:00:00
# 2017-01-02 16:00:00
# 2017-01-02 17:00:00
# 2017-01-02 18:00:00
# 2017-01-02 19:00:00
# 2017-01-02 20:00:00
# 2017-01-02 21:00:00
# 2017-01-02 22:00:00
# 2017-01-02 23:00:00
# 2017-01-03 00:00:00

# %%
def date_range(start_date, end_date):
    """
    Возвращает список дат между start_date и end_date с шагом в день.
    Если start_date > end_date, то возвращает пустой список. 
    Пример
    date_range('2018-01-01', '2018-01-07')
    [
        '2018-01-01',
        '2018-01-02',
        '2018-01-03',
        '2018-01-04',
        '2018-01-05',
        '2018-01-06',
        '2018-01-07'
    ]
    """ 
    date_range_list = []
    current_date = start_date  
    current_date_dt = datetime.strptime(start_date, '%Y-%m-%d')
    end_date_dt = datetime.strptime(end_date, '%Y-%m-%d')   
    while current_date_dt <= end_date_dt:
        date_range_list.append(current_date)        
        current_date_dt += timedelta(days=1)
        current_date = current_date_dt.strftime('%Y-%m-%d')    
    return date_range_list

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/data/data.tsv', sep='\t')
data.head()
# Out:
#       id              date  user_id  duration medium  source  cost  order_id  \
# 0  40443  05.10.2016 23:18     1010  0.000926    seo  google  0.00      6243
# 1  35044  09.10.2016 21:40     1036  0.006493    sem  yandex  0.07      6145
# 2  40177   05.10.2016 3:23     1041  0.003380  email   promo  0.00      6128
# 3  39401  05.10.2016 23:19     1041  0.000463    sem  yandex  0.03      6697
# 4  41545   01.10.2016 4:57     1042  0.006493    sem  google  0.06      4510
#
#    amount_paid
# 0         20.2
# 1         15.6
# 2         13.2
# 3          9.8
# 4         14.8

# %%
def convert_to_datetime(row):
    return datetime.strptime(row['date'], '%d.%m.%Y %H:%M')

# %%
data['datetime'] = data.apply(convert_to_datetime, axis=1)
data.head()
# Out:
#       id              date  user_id  duration medium  source  cost  order_id  \
# 0  40443  05.10.2016 23:18     1010  0.000926    seo  google  0.00      6243
# 1  35044  09.10.2016 21:40     1036  0.006493    sem  yandex  0.07      6145
# 2  40177   05.10.2016 3:23     1041  0.003380  email   promo  0.00      6128
# 3  39401  05.10.2016 23:19     1041  0.000463    sem  yandex  0.03      6697
# 4  41545   01.10.2016 4:57     1042  0.006493    sem  google  0.06      4510
#
#    amount_paid            datetime
# 0         20.2 2016-10-05 23:18:00
# 1         15.6 2016-10-09 21:40:00
# 2         13.2 2016-10-05 03:23:00
# 3          9.8 2016-10-05 23:19:00
# 4         14.8 2016-10-01 04:57:00

# %%
import time
def make_unix_time(row):
    return time.mktime(row['datetime'].timetuple())

# %%
data['unixtime'] = data.apply(make_unix_time, axis=1)
data.head()
# Out:
#       id              date  user_id  duration medium  source  cost  order_id  \
# 0  40443  05.10.2016 23:18     1010  0.000926    seo  google  0.00      6243
# 1  35044  09.10.2016 21:40     1036  0.006493    sem  yandex  0.07      6145
# 2  40177   05.10.2016 3:23     1041  0.003380  email   promo  0.00      6128
# 3  39401  05.10.2016 23:19     1041  0.000463    sem  yandex  0.03      6697
# 4  41545   01.10.2016 4:57     1042  0.006493    sem  google  0.06      4510
#
#    amount_paid            datetime      unixtime
# 0         20.2 2016-10-05 23:18:00  1.475699e+09
# 1         15.6 2016-10-09 21:40:00  1.476038e+09
# 2         13.2 2016-10-05 03:23:00  1.475627e+09
# 3          9.8 2016-10-05 23:19:00  1.475699e+09
# 4         14.8 2016-10-01 04:57:00  1.475287e+09

# %%
data.groupby(['user_id']).sum()
# Out:
#              id  duration  cost  order_id  amount_paid      unixtime
# user_id
# 1010      40443  0.000926  0.00      6243         20.2  1.475699e+09
# 1036      35044  0.006493  0.07      6145         15.6  1.476038e+09
# 1041      79578  0.003843  0.03     12825         23.0  2.951326e+09
# 1042     474297  0.035764  1.37     38389        195.8  1.770765e+10
# 1047      76173  0.003565  1.86      7984         28.6  2.951011e+09
# ...         ...       ...   ...       ...          ...           ...
# 1393      37938  0.003380  0.11      7970         10.0  1.475721e+09
# 1394      36127  0.002778  0.00      7779         12.8  1.475614e+09
# 1397      39184  0.003843  0.07      7747         20.6  1.475633e+09
# 1398      35554  0.001644  0.00      6779         18.0  1.475697e+09
# 1424     569128  0.046597  2.65     45579        237.0  2.213627e+10
#
# [124 rows x 6 columns]
