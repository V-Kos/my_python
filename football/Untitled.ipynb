# %%
import pandas as pd

data = pd.read_excel('https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/data/test.xls')  
data.head(3)
# Out:
#   U.S. Home Price and Related data, for Figure 3.1 in Robert J. Shiller, Irrational Exuberance, 3rd. Edition, Princeton University Press, 2015, as updated by author  \
# 0              See the book for description of data.
# 1  Monthly data from January 1953 for prices, all...
# 2                                                NaN
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2       Real        NaN       Real
#
#                                           Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0  Update Nominal Home Price Index, Click Additio...        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0        NaN        NaN        NaN         NaN         NaN         NaN
# 1        NaN    Nominal        NaN         NaN         NaN         NaN
# 2        NaN       Home        NaN         NaN     Nominal         NaN
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15  Unnamed: 16 Unnamed: 17 Unnamed: 18
# 0         NaN         NaN         NaN          NaN         NaN         NaN
# 1         NaN         NaN         NaN          NaN         NaN         NaN
# 2         NaN    Consumer         NaN          NaN         NaN         NaN

# %%
data = pd.read_excel("https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/data/count.xls", header=None, skiprows=2)
data[:1]
# Out:
#    0    1    2          3                                  4    5    6   7   \
# 0 NaN  NaN  NaN  НАКЛАДНАЯ  № 5764809  от "08" апреля 2018 г.  NaN  NaN NaN
#
#     8    9   10   11   12
# 0  NaN  NaN NaN  NaN  NaN

# %%
data = data.dropna(how='all')
data.head()
# Out:
#    0                                  1   \
# 0 NaN                                NaN
# 2 NaN                  Грузоотправитель:
# 4 NaN                   Грузополучатель:
# 6 NaN  Основание для отпуска: Договор №
# 9 NaN                                  №
#
#                                             2                       3   \
# 0                                          NaN               НАКЛАДНАЯ
# 2                                          NaN  ООО "Первый строитель"
# 4                                          NaN     ООО "Стройка века"
# 6                                          NaN                     NaN
# 9  Наименование товарно-материальных ценностей                     NaN
#
#                                   4                      5         6   7   \
# 0  № 5764809  от "08" апреля 2018 г.                    NaN       NaN NaN
# 2                                NaN                    NaN       NaN NaN
# 4                                NaN                    NaN       NaN NaN
# 6                                 86  от "02"апреля 2018 г.       NaN NaN
# 9                                NaN                    NaN  Ед. изм. NaN
#
#     8           9   10      11       12
# 0  NaN         NaN NaN     NaN      NaN
# 2  NaN         NaN NaN     NaN      NaN
# 4  NaN         NaN NaN     NaN      NaN
# 6  NaN         NaN NaN     NaN      NaN
# 9  NaN  Количество NaN  Цена,   Сумма,

# %%
data.iloc[0, 4][2:9]
# Out:
# '5764809'

# %%
table = data.iloc[6:8, [1, 2, 6, 9, 11, 12]]
table
# Out:
#    1                      2   6   9     11     12
# 11  1  Велосипед "Спринтер"   шт   5  9000  45000
# 12  2    Велосипед "Малютка"  шт  10  3500  35000
