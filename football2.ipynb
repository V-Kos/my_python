# %%
import pandas as pd
url = "https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/data/football.csv"
football = pd.read_csv(url)
football.head()
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
small_football = football[football.columns[1:8]].head(25)
small_football
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
small_football = football[football.columns[1:8]].head(25)
small_football
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
s = small_football['Nationality'].value_counts()
s
# Out:
# Spain        4
# Uruguay      3
# Belgium      3
# Germany      3
# Argentina    3
# France       2
# Brazil       1
# England      1
# Portugal     1
# Italy        1
# Slovenia     1
# Poland       1
# Croatia      1
# Name: Nationality, dtype: int64

# %%
s.index
# Out:
# Index(['Spain', 'Uruguay', 'Belgium', 'Germany', 'Argentina', 'France',
#        'Brazil', 'England', 'Portugal', 'Italy', 'Slovenia', 'Poland',
#        'Croatia'],
#       dtype='object')

# %%
s.index[0]
# Out:
# 'Spain'

# %%
len(s.index)
# Out:
# 13

# %%
s['Germany']
# Out:
# 3

# %%
s.loc[s > 1]
# Out:
# Spain        4
# Uruguay      3
# Belgium      3
# Germany      3
# Argentina    3
# France       2
# Name: Nationality, dtype: int64

# %%
#Сколько футбольных клубов представлено в датасете
ss=small_football['Club'].value_counts()
len(ss)
# Out:
# 10

# %%
#Как называется футбольный клуб, представленный наименьшим количеством игроков в датасете?
s.index[-1]
# Out:
# 'Croatia'

# %%
#Данные об игроках каких позиций (Position) занимают более 10% датасета?
small_football['Position'].value_counts(normalize=True)>0.1
# Out:
# GK      True
# ST      True
# RCM    False
# LF     False
# LCM    False
# CB     False
# CDM    False
# CAM    False
# RCB    False
# LDM    False
# LW     False
# RF     False
# LCB    False
# LS     False
# RS     False
# Name: Position, dtype: bool

# %%
small_football['Position'].value_counts(normalize=True)<0.1
# Out:
# GK     False
# ST     False
# RCM    False
# LF     False
# LCM    False
# CB     False
# CDM    False
# CAM    False
# RCB    False
# LDM    False
# LW     False
# RF     False
# LCB    False
# LS     False
# RS     False
# Name: Position, dtype: bool

# %%
s = small_football['Wage'].value_counts()
s
# Out:
# 205000    3
# 355000    2
# 240000    2
# 300000    1
# 130000    1
# 225000    1
# 455000    1
# 340000    1
# 315000    1
# 565000    1
# 405000    1
# 215000    1
# 380000    1
# 285000    1
# 145000    1
# 290000    1
# 125000    1
# 200000    1
# 420000    1
# 94000     1
# 260000    1
# Name: Wage, dtype: int64

# %%
s = small_football['Wage'].value_counts(bins=4)
s
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
small_football.loc[(small_football['Wage'] > s.index[3].left) & 
                   (small_football['Wage'] <= s.index[3].right)]
# Out:
#         Name  Age Nationality          Club      Value    Wage Position
# 0   L. Messi   31   Argentina  FC Barcelona  110500000  565000       RF
# 7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000       RS

# %%
#Задание 1
s=football[football.Nationality=="Spain"].Wage.value_counts(bins=4)
s
# Out:
# (620.999, 95750.0]      651
# (95750.0, 190500.0]      11
# (190500.0, 285250.0]      6
# (285250.0, 380000.0]      3
# Name: Wage, dtype: int64

# %%
s.unique()[-1]/sum(s.unique()[0:3])
# Out:
# 0.004491017964071856

# %%
#Задание 2
football[football.Club=="Manchester United"].Nationality.count()
# Out:
# 20

# %%
#Задание 3
football[(football.Nationality  == "Brazil")&(football.Club=="Juventus")].Name.unique()[0],football[(football.Nationality  == "Brazil")&(football.Club=="Juventus")].Name.unique()[1]
# Out:
# ('Alex Sandro', 'Douglas Costa')

# %%
#Задание 4
football[football.Age>35].Club.max()
# Out:
# 'Zagłębie Sosnowiec'

# %%
#Задание 5
ss=football[football.Nationality=="Argentina"].Age.value_counts(bins=4)
ss.unique()[-1]
# Out:
# 49

# %%
round(football[(football.Nationality == 'Spain')&(football.Age==21)].Name.count()/football[football.Nationality == 'Spain'].Name.count()*100,2)
# Out:
# 11.77
